# %%
#!pip install spotipy --upgrade
# %reload_ext nb_black

# %%
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
from statsmodels.stats.multitest import multipletests
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from non_param_effect_size import calc_non_param_ci, cles_ind, rbc_ind

# %matplotlib inline

# %%
large = pd.read_csv("../data/spotify_dataset.csv")
large.head()

test = large.sample(n=5000)

# gen.to_csv("../data/sampled_set.csv"

# %%
test.head()
# Out:
#         acousticness                                   artists  danceability  \
# 165311        0.7770                          ['Milt Jackson']         0.556
# 42539         0.4910                           ['João Donato']         0.578
# 72326         0.9910  ['Johann Sebastian Bach', 'Glenn Gould']         0.279
# 103920        0.3060                 ['Maria Conchita Alonso']         0.659
# 62331         0.0581                           ['Real Estate']         0.484
#
#         duration_ms  energy  explicit                      id  \
# 165311       567413   0.335         0  6linBr32WmoP56Y2N26isX
# 42539        148000   0.422         0  04dvnkrUcGqm318O9ZdpeY
# 72326         97227   0.130         0  7Kl0Izq64TwgnVMPkhkefI
# 103920       258573   0.307         0  36AZfm9TMpqDe0a97eQHZ5
# 62331        301027   0.782         0  7MtLm4K8qfXH7vDYlE4N6D
#
#         instrumentalness  key  liveness  loudness  mode  \
# 165311          0.000072    0    0.2000   -18.281     1
# 42539           0.005530    2    0.0682   -15.912     0
# 72326           0.890000   10    0.1270   -26.345     1
# 103920          0.000001    4    0.1620   -16.994     1
# 62331           0.153000    9    0.2840    -5.407     0
#
#                                              name  popularity release_date  \
# 165311                        Plenty, Plenty Soul          35   1975-01-01
# 42539                            Sugarcane Breeze          20         1965
# 72326   Invention No. 14 in B-Flat Major, BWV 785          16         1963
# 103920                                 Acaríciame          53   1986-01-01
# 62331                                Green Aisles          43   2011-10-18
#
#         speechiness    tempo  valence  year
# 165311       0.0565  115.923    0.369  1975
# 42539        0.0343  150.233    0.826  1965
# 72326        0.0434  103.133    0.776  1963
# 103920       0.0331  137.998    0.462  1986
# 62331        0.0273  104.104    0.565  2011

# %%
test.hist(figsize=(15, 10))
plt.show()

# %%
large.hist(figsize=(15, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F830054088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F82DF89808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F82CA0D708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F82E2E2CC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F831C7F848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F83314D048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F831C64DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F82CA14CC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F831C59108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F833114148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F83003C1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F8322CEB08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F82C9D81C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F8363AE308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F833160A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F831CAB048>]],
#       dtype=object)
